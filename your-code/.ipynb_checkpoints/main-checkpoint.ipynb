# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import matplotlib
import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv("Temp_states.csv")

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes

#Tenemos tres variables. City y State son object. Temperature es una variable float
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[temp["State"] == "New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp[temp["State"] == "New York"].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp["Temperature"] > 15]
#temp[temp.Temperature>15]  es otra opción
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
#temp.loc[temp.Temperature>15, "City"]
#temp.loc[temp["Temperature"] > 15, "City"]
temp.loc[temp.Temperature>15, ["City", 'Temperature']]   #Las tres están bien
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp.loc[(temp["Temperature"] >15) & (temp["Temperature"]<20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby(["State"]).mean()
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv("employee.csv")

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes

#Tenemos 5 variables que son objectec y dos variables que son interger
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here

histograma1 = employee["Years"].plot.hist()

#En el histograma de años trajados nos damos cuenta que la mayoría de los empleados tienen trabajando 3 años en la empresa
#Hay un empleado que tiene 1 año trabajando
#Hay dos empleados más veteranos que tienen 8 años trabajando

# %%
histograma2 = employee["Salary"].plot.hist()
#hay una brecha salarial de ingreso entre los empleados. Más de la mitad tienen salarios de hasta 35, mientras otros ganan
#55 y 60, con dos ganando 70.

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[employee["Salary"] == 30]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee["Name"] == "David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee["Name"] == "David"]["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee["Title"] == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee["Title"] == "associate") & (employee["Salary"] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby(["Years"]).mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby(["Title",]).mean()
# Out:
#            Years     Salary
# Title
# VP          8.00  70.000000
# analyst     2.25  32.500000
# associate   4.00  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
#
#
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
import matplotlib
# %matplotlib inline

employee.boxplot()

# %%
# print first quartile here
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby(["Gender"]).mean()

#Hay una diferencia de 2.5
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby(["Department"]).agg(["mean", "max", "min"])
# Out:
#                Years         Salary
#                 mean max min   mean max min
# Department
# HR          4.666667   8   2  45.00  70  30
# IT          4.500000   8   1  48.75  70  30
# Sales       2.500000   3   2  55.00  55  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv("Orders.csv")

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes

#Tenemos 8 int variables, 3 object variable and 2 float
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
orders.head(5)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here

#Entiendo al Purcharse Price como precio unitario
orders.UnitPrice.mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
# your answer here
orders.UnitPrice.min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders[orders["Country"] == "Spain"]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 13974        21565     538095     22504  2010     12    4    14
# 13975        21566     538095     22212  2010     12    4    14
# 13976        21567     538095     22953  2010     12    4    14
# 13977        21568     538095     84818  2010     12    4    14
# 13978        21569     538095     21114  2010     12    4    14
# 13979        21570     538095     84692  2010     12    4    14
# 13980        21571     538095     22796  2010     12    4    14
# 13981        21572     538095     40001  2010     12    4    14
# 13982        21573     538095     22646  2010     12    4    14
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here

#No necesito hacer el count. De la anterior te dice que tienes 2,485 rows

orders_Spain = pd.DataFrame(orders[orders["Country"] == "Spain"])
orders_Spain.Country.value_counts()

#O la versión de Diego
orders[orders["Country"] == "Spain"]["Country"].value_counts()
# Out:
# Spain    2485
# Name: Country, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[orders["Quantity"] > 50]["CustomerID"]
# Out:
# 46        13748
# 83        15291
# 96        14688
# 102       14688
# 174       16029
# 175       16029
# 176       16029
# 177       16029
# 178       16029
# 179       16029
# 180       16029
# 215       17511
# 217       17511
# 218       17511
# 219       17511
# 222       17511
# 223       17511
# 225       17511
# 231       17511
# 232       17511
# 245       13408
# 246       13408
# 247       13408
# 248       13408
# 376       12791
# 406       14045
# 673       13255
# 718       13694
# 719       13694
# 720       13694
#           ...
# 397113    18102
# 397114    18102
# 397115    18102
# 397116    18102
# 397117    18102
# 397118    18102
# 397119    17949
# 397120    17949
# 397155    13077
# 397330    12433
# 397336    12433
# 397344    12433
# 397351    12433
# 397371    12433
# 397372    12433
# 397380    12433
# 397448    17490
# 397451    16446
# 397454    17389
# 397471    15694
# 397563    12985
# 397572    12985
# 397586    12985
# 397622    17754
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders.loc[(orders["Country"] =="Spain") & (orders["Quantity"] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here 
orders.loc[(orders["amount_spent"] == 0.0)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here   #checar
orders[orders['Description'].str.contains("lunch bag")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year   month  day  hour  \
# 93              93     536378     20725  2010  August    3     9
# 172            174     536385     22662  2010  August    3     9
# 354            363     536401     22662  2010  August    3    11
# 359            368     536401     20725  2010  August    3    11
# 360            369     536401     22382  2010  August    3    11
# 361            370     536401     20726  2010  August    3    11
# 362            371     536401     22384  2010  August    3    11
# 402            411     536404     22383  2010  August    3    11
# 403            412     536404     20728  2010  August    3    11
# 404            413     536404     20727  2010  August    3    11
# 532            541     536412     20728  2010  August    3    11
# 533            542     536412     22382  2010  August    3    11
# 535            544     536412     22662  2010  August    3    11
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here   #checar
orders.loc[(orders["Description"] == "lunch bag") & (orders["year"] == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 49326        80323     543037     21908  2011      2    3    16
# 49327        80324     543037     22412  2011      2    3    16
# 49328        80325     543037    79066K  2011      2    3    16
# 49329        80326     543037    79191C  2011      2    3    16
# 49330        80327     543037     22348  2011      2    3    16
# 49331        80328     543037    84086C  2011      2    3    16
# 49332        80329     543037     22551  2011      2    3    16
# 49333        80330     543037     22557  2011      2    3    16
# 49334        80331     543037     21832  2011      2    3    16
# 49335        80332     543037     21915  2011      2    3    16
# 49336        80333     543037     22620  2011      2    3    16
# 49337        80334     543037     21171  2011      2    3    16
# 49338        80335     543037      POST  2011      2    3    16
# 49339        80336     543037     21864  2011      2    3    16
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here   #checar
import seaborn as sns
# %matplotlib inline

# %%
#orders[orders["amount_spent"].boxplot()
#df[df['type']=='X'].boxplot(by='Letter2')
#orders[orders["Country"]=="Spain"].bloxplot(by="amount_spent")
#orders.boxplot(column="amount_spent").("Country")


spent_Spain = orders[orders["Country"]=="Spain"]
spent_Spain.boxplot("amount_spent")

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders.loc[(orders["month"] == "August")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year   month  day  hour  \
# 0                0     536365    85123A  2010  August    3     8
# 1                1     536365     71053  2010  August    3     8
# 2                2     536365    84406B  2010  August    3     8
# 3                3     536365    84029G  2010  August    3     8
# 4                4     536365    84029E  2010  August    3     8
# 5                5     536365     22752  2010  August    3     8
# 6                6     536365     21730  2010  August    3     8
# 7                7     536366     22633  2010  August    3     8
# 8                8     536366     22632  2010  August    3     8
# 9                9     536367     84879  2010  August    3     8
# 10              10     536367     22745  2010  August    3     8
# 11              11     536367     22748  2010  August    3     8
# 12              12     536367     22749  2010  August    3     8
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here #checar
orders.groupby(["Country"])["month"].value_counts()
# Out:
# Country               month
# Australia             August      1185
# Austria               August       398
# Bahrain               August        17
# Belgium               August      2031
# Brazil                August        32
# Canada                August       151
# Channel Islands       August       748
# Cyprus                August       614
# Czech Republic        August        25
# Denmark               August       380
# EIRE                  August      7238
# European Community    August        60
# Finland               August       685
# France                August      8342
# Germany               August      9042
# Greece                August       145
# Iceland               August       182
# Israel                August       248
# Italy                 August       758
# Japan                 August       321
# Lebanon               August        45
# Lithuania             August        35
# Malta                 August       112
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby(["Country"])["amount_spent"].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders.groupby(["Country"])["amount_spent"].max()
# Out:
# Country
# Australia                 1718.40
# Austria                    360.00
# Bahrain                    120.00
# Belgium                    165.00
# Brazil                     175.20
# Canada                     550.94
# Channel Islands            408.00
# Cyprus                     320.69
# Czech Republic              70.80
# Denmark                    428.40
# EIRE                      2365.20
# European Community          60.00
# Finland                    551.20
# France                    4161.06
# Germany                    876.00
# Greece                     175.20
# Iceland                    249.60
# Israel                     350.40
# Italy                      300.00
# Japan                     3794.40
# Lebanon                    153.00
# Lithuania                  122.40
# Malta                      455.00
# Netherlands               4992.00
# Norway                     700.00
# Poland                     120.00
# Portugal                  1241.98
# ...

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby(["year"])["amount_spent"].mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
